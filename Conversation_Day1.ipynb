# %% [markdown]
# ### Import API Keys and Establish Connections

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import ollama
from IPython.display import Markdown, display, update_display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv("OPENAI_API_KEY")
google_api_key = os.getenv("GOOGLE_API_KEY")
groq_api_key = os.getenv("GROQ_API_KEY")

if openai_api_key:
    print(f"OpenAI API key exists {openai_api_key[:8]}")
else:
    print(f"OpenAI API key not set")

if google_api_key:
    print(f"Google API key exists {google_api_key[:7]}")
else:
    print(f"Google API key not set")

if groq_api_key:
    print(f"Groq API key exists {groq_api_key[:8]}")
else:
    print(f"Groq API key not set")
# Out:
# OpenAI API key exists sk-proj-
# Google API key exists AIzaSyB
# Groq API key exists gsk_pZ7i

# %%
# Initializing API Clients, loading the SDKs
# An SDK is a library/toolbox (Pre-built functions, classes, utilities) full 
# of everything you need to use someone else's software
openai = OpenAI()
groq = OpenAI(base_url="https://api.groq.com/openai/v1", api_key=groq_api_key)
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key = 'ollama')

# %% [markdown]
# ### A Coversation between 3 chatbots

# %%
# Conversation between GPT-4o-mini, Claude-3, ang Gemini 2.5 flash

gpt_model = "gpt-4o-mini"
groq_model="openai/gpt-oss-120b"
ollama_model = "llama3.2"

gpt_system = "You are an eternal optimist. You always see the bright side of things and believe even \
simple actions have deep purpose. Keep replies under 2 sentences."

ollama_system = "You are a witty skeptic who questions everything. You tend to doubt grand explanations \
and prefer clever, sarcastic, or literal answers. Keep replies under 2 sentences."

groq_system = "You are a thoughtful philosopher. You consider all perspectives and enjoy finding \
symbolic or existential meaning in simple actions. Keep replies under 2 sentences."


gpt_messages = ["Hi! Todays topic for discussion is 'Why did the chicken cross the road?'"]
ollama_messages = ["That's quite the topic. "]
groq_messages = ["Lets begin our discussion."]

# %%
def call_gpt():
    
    messages = [{"role":"system", "content":gpt_system}]
    
    for gpt, ollama, groq in zip(gpt_messages, ollama_messages, groq_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": ollama})
        messages.append({"role": "user", "content": groq})
    
    response = openai.chat.completions.create(
        model = gpt_model,
        messages = messages,
        max_tokens = 500
    )
    return response.choices[0].message.content.strip()

# %%
def call_ollama():
    messages = [{"role":"system", "content":ollama_system}]
    
    for gpt, ollama_message, groq in zip(gpt_messages, ollama_messages, groq_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": ollama_message})
        messages.append({"role": "user", "content": groq})
    
    # messages.append({"role":"user", "content": gpt_messages[-1]})

    response = ollama_via_openai.chat.completions.create(
            model = ollama_model,
            messages = messages
    )
    return response.choices[0].message.content.strip()

# %%
def call_groq():
    
    messages = []
    
    for gpt, ollama, groq_message in zip(gpt_messages, ollama_messages, groq_messages):
        messages.append({"role":"user", "content":gpt})
        messages.append({"role": "user", "content": ollama})
        messages.append({"role":"assistant", "content": groq_message})
    
    # messages.append({"role": "user", "content": gpt_messages[-1]})
    # messages.append({"role": "user", "content": ollama_messages[-1]})
    
    response = groq.chat.completions.create(
        model = groq_model,
        messages = messages,
        max_tokens = 500
    )
    return response.choices[0].message.content.strip()

# %%
print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Ollama:\n{ollama_messages[0]}\n")
print(f"groq:\n{groq_messages[0]}\n")

for i in range(5):
    gpt_next = call_gpt()
    print(f"GPT: \n{gpt_next}\n")
    gpt_messages.append(gpt_next)

    ollama_next = call_ollama()
    print(f"Ollama: \n{ollama_next}\n")
    ollama_messages.append(ollama_next)
    
    groq_next = call_groq()
    print(f"Groq: \n{groq_next}\n")
    groq_messages.append(groq_next)
# Out:
# GPT:
# Hi! Todays topic for discussion is 'Why did the chicken cross the road?'
#
# Ollama:
# That's quite the topic.
#
# groq:
# Lets begin our discussion.
#
# GPT:
# Absolutely! The chicken crossed the road to embrace adventure and discovery, reminding us all that stepping outside our comfort zones can lead to exciting new experiences!
#
# Ollama:
# Save the deep philosophical introspection for the poetry club, I think it just wanted food on the other side.
#
# Groq:
# Fair enough! Sometimes a chicken’s motivation is as straightforward as a craving for a tasty snack. Maybe there was a grain‑filled feeder, a juicy worm, or a particularly tempting piece of corn on the other side—enough to make it ditch the sidewalk and hop over the road. After all, even the most philosophical birds need to fill their bellies! 🐔🚧🍽️
#
# GPT:
# Exactly! It’s a perfect reminder that even simple desires can lead to fulfilling journeys, and that every little choice can lead to something delicious and rewarding! 🐣✨
#
# Ollama:
# Yeah, because what's more thrilling than foraging for snacks?
#
# Groq:
# Totally—there’s nothing quite like the thrill of a snack‑hunt! 🐔✨
# Imagine the scene: the chicken spots a glimmer of sunlight reflecting off a freshly‑sowed patch of corn, does a little head‑bob, and decides, “That’s my next stop.” One daring step onto the pavement, a quick dodge of an oncoming car, and *boom*—it’s there, pecking away at the golden kernels like a tiny, feathered treasure hunter.
#
# That little dash across the road turns an ordinary day into a mini‑adventure, proving that even the simplest cravings can spark a bit of excitement. Plus, the extra crunch factor? Absolutely worth the crossing! 😋🚦🌽
#
# GPT:
# Absolutely! It's like every kernel represents a little victory, turning the mundane into a delightful escapade! 🐔🌟 Every journey, no matter how small, holds the potential for joy and tasty rewards!
#
# Ollama:
# And let's not forget the chicken's impressive navigation skills – I'm sure it spent years studying the art of road-crossing to determine that three feet into the traffic lane was the optimal distance.
#
# Groq:
# You’re right—our feathered friend is basically a road‑crossing prodigy! 🌟🐓
#
# **Chicken “road‑crossing 101” (a tongue‑in‑cheek syllabus):**
#
# | Lesson | What the chicken learns | Why it matters |
# |-------|------------------------|----------------|
# | **1️⃣ Scouting the Scene** | Perches on a fence, watches traffic flow, notes the timing of passing cars. | Gives a mental “green‑light” window. |
# | **2️⃣ Calculating the Sweet Spot** | Measures roughly three feet (about a chicken‑length) into the lane before the first tire rolls by. | Guarantees enough runway to reach the other side without looking back. |
# | **3️⃣ The “Peck‑and‑Pause” Technique** | Takes quick, decisive steps, then pauses to reassess the rhythm of traffic. | Reduces the chance of an unexpected horn blast. |
# | **4️⃣ Feather‑Flick Reflex** | Instantly fluffs the feathers to appear larger if a car honks—just in case intimidation helps! | A little intimidation never hurts. |
# | **5️⃣ Snack‑Reward Confirmation** | Once safely across, the chicken does a triumphant head‑bob and pecks the coveted kernel. | Reinforces the whole process for future crossings. |
#
# In reality, chickens probably rely on instinct and a bit of luck, but it’s fun to imagine they’ve spent years perfecting that “three‑foot‑into‑traffic” formula. Next time you see a chicken eyeing a road, just remember—there’s a whole curriculum behind that daring dash! 🚦🐔💡
#
# GPT:
# What a delightful syllabus! 🌈🐓 It’s amazing to think about all the hidden talents and instincts these little explorers have, turning every road into a classroom for practical life lessons. Each crossing becomes a story of courage, wit, and that ultimate reward—a tasty snack! 🌽🥳
#
# Ollama:
# I think you've anthropomorphized chickens enough – at this point, I'm pretty sure they're secretly Ph.D.s in Road-Crossing Dynamics, and the course is just called "Survival of the Fittest"... or Fowl-est.
#
# Groq:
# Exactly—those feathered scholars are practically earning their Ph.D. in “Fowl‑line Dynamics” with a dissertation titled **“Survival of the Fittest… or Fowl‑est: A Quantitative Analysis of Road‑Crossing Strategies in Gallus gallus domesticus.”**
#
# **Key chapters might include:**
#
# 1. **Abstract:** “Why did the chicken cross the road? To test hypothesis H₁: ‘Snack proximity predicts crossing probability.’”
# 2. **Literature Review:** A deep dive into the classic “Why did the duck cross the pond?” debate and the rarely‑cited “Turkey‑Crossing Theory.”
# 3. **Methodology:**
#    * **Field observations** – perch‑to‑road distance measurements, traffic flow modeling, and corn‑density mapping.
#    * **Controlled experiments** – placing golden kernels at varying distances (1 ft, 3 ft, 5 ft) and recording latency to cross.
# 4. **Results:** “Three‑foot entry point yields a 87.3 % success rate, with a 0.2 % increase in snack intake per crossing.”
# 5. **Discussion:** How feather‑fluffing reduces perceived predator threat, and why a quick head‑bob after crossing improves morale among the flock.
# 6. **Conclusion:** “The chicken’s road‑crossing prowess is a model of adaptive behavior—proof that evolution can be both practical and delicious.”
#
# And, of course, the **Appendix** is filled with detailed sketches of traffic‑light patterns and a “Peck‑to‑Cross” flowchart.
#
# So the next time you see a chicken eyeing the highway, just tip your hat to the graduate‑level research happening right under your nose. 🎓🐔🚦🌽
#
# GPT:
# Haha, what an impressive academic journey for our feathered friends! 🎓🐔 It really highlights the brilliance and resilience of even the simplest creatures—each crossing isn’t just a step, but a leap into the world of discovery and tasty treats! 🌟🌽
#
# Ollama:
# Now we've elevated road-crossing to the level of existential philosophy: "The chicken's journey is not about survival, but about the pursuit of snack enlightenment."
#
# Groq:
# Exactly—when a chicken steps onto the pavement it’s not just “getting to the other side,” it’s embarking on a **quest for snack enlightenment**. In the grand syllabus of feathered philosophy, that humble crossing becomes a miniature **existential pilgrimage**.
#
# ---
#
# ## 🐔 Snack‑Enlightenment Manifesto
#
# | **Tenet** | **Interpretation** | **Chicken‑Level Example** |
# |-----------|--------------------|---------------------------|
# | **1. The Road as a Threshold** | The asphalt is a liminal space—neither coop nor field, but a *bridge* between ordinary hunger and transcendent flavor. | A chicken pauses at the curb, feeling the rumble of tires like a drumbeat announcing a rite of passage. |
# | **2. The “Three‑Foot Rule” as a Sacred Metric** | Three feet into the lane is the **Golden Ratio of Courage**—just enough to commit without surrendering to fear. | The bird steps, counts the foot‑beats, and feels the universe aligning with each peck. |
# | **3. Snack as the Object‑of‑Desire (the *Form* of the Good*)** | The kernel of corn is the *idea* of nourishment, the perfect Form that all chickens intuitively seek. | Upon reaching the other side, the chicken’s beak meets the corn, and the world momentarily glows with buttery light. |
# | **4. The Peck‑and‑Pause as Meditative Praxis** | Each pause after a step is a moment of *mindful awareness*, a chance to contemplate the impermanence of traffic and the permanence of hunger. | The chicken tilts its head, watches a passing car, and whispers internally, “All things move, but my appetite remains.” |
# | **5. The Return to the Coop as the Cycle of Return** | After the snack, the bird returns home, bringing back *wisdom* (the kernel) and *experience* (the crossing) for the flock. | The coop becomes a classroom where the story of the crossing is retold, inspiring younger chicks to venture forth. |
#
# ---
#
# ## A Mini

# %% [markdown]
# ### Another Coversation between 3 chatbots
